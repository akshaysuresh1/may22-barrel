# %% [markdown]
# ### Quadratic Regression Model
#
# Our [previous investigation](https://github.com/akshaysuresh1/may22-barrel/blob/main/Modeling/npk_cluster_trends.ipynb) informed us of a predominantly linear relationship between fertilizer consumption per area and rice yield across most clusters. As a first attempt, we fit a [simple linear regression model](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html) to the observed variation of fertilizer input with rice yield for each cluster. Now, we are using a quadratic regression model with [Ridge](https://towardsdatascience.com/ridge-regression-python-example-f015345d936b) regularization

# %%
# Load relevant packages.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# sklearn model
from sklearn.model_selection import train_test_split, KFold
# from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as mse
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge

sns.set_style('whitegrid')


data_dir = "."
# df = pd.read_csv('../Final_data/rice_yield_clusters.csv')
df = pd.read_csv('rice_yield_clusters.csv')

# Compute fertilizer consumption per unit area.
df['N_per_area'] = df['nitrogen']/df['RICE.AREA..1000.ha.']
df['P_per_area'] = df['phosphate']/df['RICE.AREA..1000.ha.']
df['K_per_area'] = df['potash']/df['RICE.AREA..1000.ha.']

N_clusters = df['Cluster'].max() - df['Cluster'].min() + 1
print('No. of clusters in data = %d'% (N_clusters))


poly_reg = PolynomialFeatures(degree=2)
# X_poly = poly_reg.fit_transform(x)

# Create K-fold object
nfold = 10
kfold = KFold(nfold, random_state = 614, shuffle=True)

# Store mean-squared errors on test NPK data for each cluster.
N_rmse_test = np.zeros(N_clusters)
P_rmse_test = np.zeros(N_clusters)
K_rmse_test = np.zeros(N_clusters)

# Loop over clusters.
for i in range(N_clusters):
    selection = df[df['Cluster']==i+1]
    
    # Train-test split
    df_train, df_test = train_test_split(selection.copy(), test_size=0.2, shuffle=True, random_state=440)
    print('Cluster %d'% (i+1))
    print('Size of test set = %d'% (len(df_test)))
    
    # Create model objects, one each for N, P, and K.
    slr_N = Ridge(alpha=50, copy_X=True) 
    slr_P = Ridge(alpha=50, copy_X=True) 
    slr_K = Ridge(alpha=50, copy_X=True) 
    
    j = 0 # k-fold index
    # Loop through k-fold.
    for train_index, test_index in kfold.split(df_train):
        # Training set
        df_tt = df_train.iloc[train_index]
        # Holdout set
        df_ho = df_train.iloc[test_index]
        print('Fold %d: Train/validation data size = [%d, %d]'% (j+1, len(df_tt), len(df_ho)))

        # Fit models to NPK data.
        slr_N.fit(poly_reg.fit_transform(df_tt['RICE.YIELD..kg.per.ha.'].values.reshape(-1,1)), df_tt['N_per_area'])
        slr_P.fit(poly_reg.fit_transform(df_tt['RICE.YIELD..kg.per.ha.'].values.reshape(-1,1)), df_tt['P_per_area'])
        slr_K.fit(poly_reg.fit_transform(df_tt['RICE.YIELD..kg.per.ha.'].values.reshape(-1,1)), df_tt['K_per_area'])
        
        # Obtain predictions on the holdout set.
        pred_N = slr_N.predict(poly_reg.fit_transform(df_ho['RICE.YIELD..kg.per.ha.'].values.reshape(-1,1)))
        pred_P = slr_P.predict(poly_reg.fit_transform(df_ho['RICE.YIELD..kg.per.ha.'].values.reshape(-1,1)))
        pred_K = slr_K.predict(poly_reg.fit_transform(df_ho['RICE.YIELD..kg.per.ha.'].values.reshape(-1,1)))
        
        # Compute root mean squared error (RMSE) on the holdout set.
        rmse_fold_N = mse(df_ho['N_per_area'], pred_N, squared=False)
        rmse_fold_P = mse(df_ho['P_per_area'], pred_P, squared=False)
        rmse_fold_K = mse(df_ho['K_per_area'], pred_K, squared=False)
        print('N_RMSE = %.4f, P_RMSE = %.4f, K_RMSE = %.4f\n'% (rmse_fold_N, rmse_fold_P, rmse_fold_K))
        j+=1
  
    # Predict on test data.
    test_pred_N = slr_N.predict(poly_reg.fit_transform(df_test['RICE.YIELD..kg.per.ha.'].values.reshape(-1,1)))
    test_pred_P = slr_P.predict(poly_reg.fit_transform(df_test['RICE.YIELD..kg.per.ha.'].values.reshape(-1,1)))
    test_pred_K = slr_K.predict(poly_reg.fit_transform(df_test['RICE.YIELD..kg.per.ha.'].values.reshape(-1,1)))
    
    # Record RMSE on test data.
    N_rmse_test[i] = mse(df_test['N_per_area'], test_pred_N, squared=False)
    P_rmse_test[i] = mse(df_test['P_per_area'], test_pred_P, squared=False)    
    K_rmse_test[i] = mse(df_test['K_per_area'], test_pred_K, squared=False)    
    print('RMSE on N test data = %.4f'% (N_rmse_test[i]))
    print('RMSE on P test data = %.4f'% (P_rmse_test[i]))
    print('RMSE on K test data = %.4f'% (K_rmse_test[i]))
    
    # Line fit for plotting
    x = np.linspace(0.95*selection['RICE.YIELD..kg.per.ha.'].min(),
                    1.05*selection['RICE.YIELD..kg.per.ha.'].max(), 1000)
    y_N = slr_N.predict(poly_reg.fit_transform(x.reshape(-1,1)))
    y_P = slr_P.predict(poly_reg.fit_transform(x.reshape(-1,1)))
    y_K = slr_K.predict(poly_reg.fit_transform(x.reshape(-1,1)))
    
    # Compute prediction on training data.
    train_pred_N = slr_N.predict(poly_reg.fit_transform(df_train['RICE.YIELD..kg.per.ha.'].values.reshape(-1,1)))
    train_pred_P = slr_P.predict(poly_reg.fit_transform(df_train['RICE.YIELD..kg.per.ha.'].values.reshape(-1,1)))
    train_pred_K = slr_K.predict(poly_reg.fit_transform(df_train['RICE.YIELD..kg.per.ha.'].values.reshape(-1,1)))
    
    # Compute residual on training data.
    train_residual_N = df_train['N_per_area'] - train_pred_N
    train_residual_P = df_train['P_per_area'] - train_pred_P
    train_residual_K = df_train['K_per_area'] - train_pred_K    
    
    # Plotting
    fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(12,12))
    # Row 0, column 0: Nitrogen consumption (kg/ha) vs. rice yield (kg/ha)
    l1 = axes[0,0].scatter(x=df_train['RICE.YIELD..kg.per.ha.'], y=df_train['N_per_area'], c='lightgray', alpha=0.5,
                     label='Training data')
    l2 = axes[0,0].scatter(x=df_test['RICE.YIELD..kg.per.ha.'], y=df_test['N_per_area'], c='cornflowerblue', alpha=0.5,
                     label='Test data') 
    l3, = axes[0,0].plot(x, y_N, '-k', label='Fit')
    axes[0,0].set_xlabel('Annual rice yield (kg/ha)', fontsize=14)
    axes[0,0].set_ylabel('N consumption (kg/ha)', fontsize=14)
    # Row 0, column 1: Residual on training data vs. predicted N consumption
    axes[0,1].scatter(x=train_pred_N, y=train_residual_N, c='lightgray', alpha=0.5)
    axes[0,1].set_xlabel('Predicted N consumption (kg/ha)', fontsize=14)
    axes[0,1].set_ylabel('Residuals (kg/ha)', fontsize=14)
    # Row 1, column 0: Phosphate consumption (kg/ha) vs. rice yield (kg/ha)
    axes[1,0].scatter(x=df_train['RICE.YIELD..kg.per.ha.'], y=df_train['P_per_area'], c='lightgray', alpha=0.5)
    axes[1,0].scatter(x=df_test['RICE.YIELD..kg.per.ha.'], y=df_test['P_per_area'], c='cornflowerblue', alpha=0.5) 
    axes[1,0].plot(x, y_P, '-k')
    axes[1,0].set_xlabel('Annual rice yield (kg/ha)', fontsize=14)
    axes[1,0].set_ylabel('P consumption (kg/ha)', fontsize=14)
    # Row 1, column 1: Residual on training data vs. predicted P consumption
    axes[1,1].scatter(x=train_pred_P, y=train_residual_P, c='lightgray', alpha=0.5)
    axes[1,1].set_xlabel('Predicted P consumption (kg/ha)', fontsize=14)
    axes[1,1].set_ylabel('Residuals (kg/ha)', fontsize=14)
    # Row 2, column 0: Potash consumption (kg/ha) vs. rice yield (kg/ha)
    axes[2,0].scatter(x=df_train['RICE.YIELD..kg.per.ha.'], y=df_train['K_per_area'], c='lightgray', alpha=0.5)
    axes[2,0].scatter(x=df_test['RICE.YIELD..kg.per.ha.'], y=df_test['K_per_area'], c='cornflowerblue', alpha=0.5) 
    axes[2,0].plot(x, y_K, '-k')
    axes[2,0].set_xlabel('Annual rice yield (kg/ha)', fontsize=14)
    axes[2,0].set_ylabel('K consumption (kg/ha)', fontsize=14)
    # Row 2, column 1: Residual on training data vs. predicted K consumption
    axes[2,1].scatter(x=train_pred_K, y=train_residual_K, c='lightgray', alpha=0.5)
    axes[2,1].set_xlabel('Predicted K consumption (kg/ha)', fontsize=14)
    axes[2,1].set_ylabel('Residuals (kg/ha)', fontsize=14)
    # Figure settings
    fig.subplots_adjust(left=0.01, right=0.98, top=0.90, bottom=0.05, hspace=0.4)
    # Figure legend
    fig.legend((l1,l2,l3), ('Training data','Test data','Fit to training data'), loc=(0.28, 0.905),
               ncol=3, fontsize=14)
    # Figure title
    fig.suptitle('Cluster %d' % (i+1), y=1.0, fontsize=20)
    
    plt.show()
# Out:
# No. of clusters in data = 6
# Cluster 1
# Size of test set = 806
# Fold 1: Train/validation data size = [2898, 323]
# N_RMSE = 19.2084, P_RMSE = 6.8300, K_RMSE = 3.6519
#
# Fold 2: Train/validation data size = [2899, 322]
# N_RMSE = 19.6941, P_RMSE = 7.1070, K_RMSE = 4.8528
#
# Fold 3: Train/validation data size = [2899, 322]
# N_RMSE = 24.8964, P_RMSE = 12.8248, K_RMSE = 5.7129
#
# Fold 4: Train/validation data size = [2899, 322]
# N_RMSE = 20.1763, P_RMSE = 8.3804, K_RMSE = 4.5056
#
# Fold 5: Train/validation data size = [2899, 322]
# N_RMSE = 19.7046, P_RMSE = 8.3051, K_RMSE = 4.3884
#
# Fold 6: Train/validation data size = [2899, 322]
# N_RMSE = 23.2398, P_RMSE = 10.6726, K_RMSE = 4.8116
#
# Fold 7: Train/validation data size = [2899, 322]
# N_RMSE = 16.0467, P_RMSE = 7.3449, K_RMSE = 6.4502
#
# Fold 8: Train/validation data size = [2899, 322]
# N_RMSE = 21.8184, P_RMSE = 9.7655, K_RMSE = 5.1087
#
# Fold 9: Train/validation data size = [2899, 322]
# N_RMSE = 23.6716, P_RMSE = 10.5989, K_RMSE = 5.1510
#
# Fold 10: Train/validation data size = [2899, 322]
# N_RMSE = 18.6716, P_RMSE = 7.5966, K_RMSE = 5.0662
#
# RMSE on N test data = 18.6496
# RMSE on P test data = 7.4905
# RMSE on K test data = 4.1186
# Cluster 2
# Size of test set = 174
# Fold 1: Train/validation data size = [625, 70]
# N_RMSE = 8.8459, P_RMSE = 5.2186, K_RMSE = 5.9803
#
# Fold 2: Train/validation data size = [625, 70]
# N_RMSE = 18.3806, P_RMSE = 5.8339, K_RMSE = 6.1408
#
# Fold 3: Train/validation data size = [625, 70]
# N_RMSE = 9.9441, P_RMSE = 5.7144, K_RMSE = 7.1307
#
# Fold 4: Train/validation data size = [625, 70]
# N_RMSE = 8.9860, P_RMSE = 5.9105, K_RMSE = 7.8152
#
# Fold 5: Train/validation data size = [625, 70]
# N_RMSE = 11.2589, P_RMSE = 6.2210, K_RMSE = 6.7234
#
# Fold 6: Train/validation data size = [626, 69]
# N_RMSE = 12.1542, P_RMSE = 6.3045, K_RMSE = 5.8690
#
# Fold 7: Train/validation data size = [626, 69]
# N_RMSE = 12.3221, P_RMSE = 6.9905, K_RMSE = 8.3807
#
# Fold 8: Train/validation data size = [626, 69]
# N_RMSE = 12.8866, P_RMSE = 6.8464, K_RMSE = 6.8539
#
# Fold 9: Train/validation data size = [626, 69]
# N_RMSE = 10.6749, P_RMSE = 6.6590, K_RMSE = 6.5161
#
# Fold 10: Train/validation data size = [626, 69]
# N_RMSE = 11.8112, P_RMSE = 7.2962, K_RMSE = 7.4366
#
# RMSE on N test data = 11.6718
# RMSE on P test data = 6.4915
# RMSE on K test data = 6.4887
# Cluster 3
# Size of test set = 602
# Fold 1: Train/validation data size = [2166, 241]
# N_RMSE = 23.9178, P_RMSE = 9.7391, K_RMSE = 4.6255
#
# Fold 2: Train/validation data size = [2166, 241]
# N_RMSE = 18.7274, P_RMSE = 6.6352, K_RMSE = 3.8623
#
# Fold 3: Train/validation data size = [2166, 241]
# N_RMSE = 20.9396, P_RMSE = 8.1360, K_RMSE = 5.1048
#
# Fold 4: Train/validation data size = [2166, 241]
# N_RMSE = 19.0920, P_RMSE = 7.4885, K_RMSE = 3.0148
#
# Fold 5: Train/validation data size = [2166, 241]
# N_RMSE = 18.1763, P_RMSE = 6.3161, K_RMSE = 3.0062
#
# Fold 6: Train/validation data size = [2166, 241]
# N_RMSE = 19.9860, P_RMSE = 6.2331, K_RMSE = 2.5717
#
# Fold 7: Train/validation data size = [2166, 241]
# N_RMSE = 19.6696, P_RMSE = 6.5179, K_RMSE = 3.6575
#
# Fold 8: Train/validation data size = [2167, 240]
# N_RMSE = 20.3303, P_RMSE = 7.5687, K_RMSE = 3.2730
#
# Fold 9: Train/validation data size = [2167, 240]
# N_RMSE = 19.3670, P_RMSE = 7.4882, K_RMSE = 4.2297
#
# Fold 10: Train/validation data size = [2167, 240]
# N_RMSE = 19.4363, P_RMSE = 7.5253, K_RMSE = 3.3365
#
# RMSE on N test data = 21.2460
# RMSE on P test data = 7.1919
# RMSE on K test data = 3.8681
# Cluster 4
# Size of test set = 140
# Fold 1: Train/validation data size = [503, 56]
# N_RMSE = 20.6632, P_RMSE = 9.1143, K_RMSE = 9.8121
#
# Fold 2: Train/validation data size = [503, 56]
# N_RMSE = 20.1083, P_RMSE = 8.7704, K_RMSE = 9.3208
#
# Fold 3: Train/validation data size = [503, 56]
# N_RMSE = 24.9146, P_RMSE = 11.9491, K_RMSE = 14.1777
#
# Fold 4: Train/validation data size = [503, 56]
# N_RMSE = 23.5484, P_RMSE = 10.3250, K_RMSE = 13.7058
#
# Fold 5: Train/validation data size = [503, 56]
# N_RMSE = 23.2623, P_RMSE = 12.1788, K_RMSE = 13.2209
#
# Fold 6: Train/validation data size = [503, 56]
# N_RMSE = 19.8738, P_RMSE = 8.7000, K_RMSE = 10.0448
#
# Fold 7: Train/validation data size = [503, 56]
# N_RMSE = 20.3108, P_RMSE = 8.3186, K_RMSE = 11.1382
#
# Fold 8: Train/validation data size = [503, 56]
# N_RMSE = 21.3822, P_RMSE = 8.2695, K_RMSE = 9.2880
#
# Fold 9: Train/validation data size = [503, 56]
# N_RMSE = 18.5042, P_RMSE = 8.1306, K_RMSE = 8.7114
#
# Fold 10: Train/validation data size = [504, 55]
# N_RMSE = 26.2929, P_RMSE = 11.8599, K_RMSE = 15.3462
#
# RMSE on N test data = 19.4227
# RMSE on P test data = 7.7097
# RMSE on K test data = 10.1724
# Cluster 5
# Size of test set = 304
# Fold 1: Train/validation data size = [1090, 122]
# N_RMSE = 18.4960, P_RMSE = 7.4691, K_RMSE = 3.1415
#
# Fold 2: Train/validation data size = [1090, 122]
# N_RMSE = 38.1043, P_RMSE = 13.4854, K_RMSE = 3.6856
#
# Fold 3: Train/validation data size = [1091, 121]
# N_RMSE = 21.5527, P_RMSE = 8.2664, K_RMSE = 3.6272
#
# Fold 4: Train/validation data size = [1091, 121]
# N_RMSE = 21.1362, P_RMSE = 7.0917, K_RMSE = 4.2155
#
# Fold 5: Train/validation data size = [1091, 121]
# N_RMSE = 22.3957, P_RMSE = 7.6244, K_RMSE = 3.5743
#
# Fold 6: Train/validation data size = [1091, 121]
# N_RMSE = 22.0415, P_RMSE = 6.8791, K_RMSE = 3.0834
#
# Fold 7: Train/validation data size = [1091, 121]
# N_RMSE = 19.9465, P_RMSE = 7.5417, K_RMSE = 3.0295
#
# Fold 8: Train/validation data size = [1091, 121]
# N_RMSE = 22.0824, P_RMSE = 7.0782, K_RMSE = 3.3845
#
# Fold 9: Train/validation data size = [1091, 121]
# N_RMSE = 24.5430, P_RMSE = 6.5559, K_RMSE = 2.9589
#
# Fold 10: Train/validation data size = [1091, 121]
# N_RMSE = 22.3093, P_RMSE = 9.0112, K_RMSE = 3.2686
#
# RMSE on N test data = 19.4010
# RMSE on P test data = 6.4893
# RMSE on K test data = 3.8610
# Cluster 6
# Size of test set = 72
# Fold 1: Train/validation data size = [259, 29]
# N_RMSE = 21.0165, P_RMSE = 10.1914, K_RMSE = 11.5231
#
# Fold 2: Train/validation data size = [259, 29]
# N_RMSE = 36.7768, P_RMSE = 22.6111, K_RMSE = 8.5886
#
# Fold 3: Train/validation data size = [259, 29]
# N_RMSE = 17.4299, P_RMSE = 7.6363, K_RMSE = 8.0268
#
# Fold 4: Train/validation data size = [259, 29]
# N_RMSE = 24.0047, P_RMSE = 10.9263, K_RMSE = 13.6709
#
# Fold 5: Train/validation data size = [259, 29]
# N_RMSE = 30.4535, P_RMSE = 15.3390, K_RMSE = 15.4747
#
# Fold 6: Train/validation data size = [259, 29]
# N_RMSE = 28.5256, P_RMSE = 12.8450, K_RMSE = 14.1273
#
# Fold 7: Train/validation data size = [259, 29]
# N_RMSE = 16.3458, P_RMSE = 9.8776, K_RMSE = 10.8970
#
# Fold 8: Train/validation data size = [259, 29]
# N_RMSE = 15.3353, P_RMSE = 6.9098, K_RMSE = 6.7727
#
# Fold 9: Train/validation data size = [260, 28]
# N_RMSE = 14.1799, P_RMSE = 8.0444, K_RMSE = 11.2951
#
# Fold 10: Train/validation data size = [260, 28]
# N_RMSE = 41.2265, P_RMSE = 23.8753, K_RMSE = 14.3050
#
# RMSE on N test data = 37.0728
# RMSE on P test data = 22.9770
# RMSE on K test data = 16.7636
